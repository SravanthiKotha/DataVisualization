# %% [markdown]
# # Plotting with ```matplotlib```
#
# In this section, we will:
# - Create basic plots using ```matplotlib.pyplot```
# - Put axis labels and titles
# - Create multiple plots (subplots) in the same figure
# - Create common types of plots: Histograms, boxplots, scatter plots etc.
# - Working with images
#
# ```matplotlib``` is a python library. It contains the ```pyplot``` module, which is basically a collection of functions such as ```plot```, ```title```, ```show()``` etc. ```pyplot``` is one of the most commonly used module for creating a variety of plots such as line plots, bar plots, histograms etc.
#
# Let's start with the basics.

# %% [markdown]
# ## Basic Plotting, Axes Labels and Titles

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Plotting two 1-D numpy arrays
x = np.linspace(5, 100, 25)
y = np.linspace(10, 1000, 25)

plt.plot(x, y, 'y^')
plt.plot(x, y**2, 'r+')
plt.xlabel("X_axis")
plt.ylabel("Y_axis")
plt.title("Our First Plot")
plt.show()

# %%
x
# Out:
# array([  5.        ,   8.95833333,  12.91666667,  16.875     ,
#         20.83333333,  24.79166667,  28.75      ,  32.70833333,
#         36.66666667,  40.625     ,  44.58333333,  48.54166667,
#         52.5       ,  56.45833333,  60.41666667,  64.375     ,
#         68.33333333,  72.29166667,  76.25      ,  80.20833333,
#         84.16666667,  88.125     ,  92.08333333,  96.04166667,
#        100.        ])

# %%
y
# Out:
# array([  10.  ,   51.25,   92.5 ,  133.75,  175.  ,  216.25,  257.5 ,
#         298.75,  340.  ,  381.25,  422.5 ,  463.75,  505.  ,  546.25,
#         587.5 ,  628.75,  670.  ,  711.25,  752.5 ,  793.75,  835.  ,
#         876.25,  917.5 ,  958.75, 1000.  ])

# %%
(5,10)  (8.9, 51.25)
# Out:
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18028\2316764572.py:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   (5,10)  (8.9, 51.25)
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18028\2316764572.py:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   (5,10)  (8.9, 51.25)
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18028\2316764572.py:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   (5,10)  (8.9, 51.25)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 (5,10)  (8.9, 51.25)
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# Let's see how to put labels and the x and y axes and the chart title.

# %%
# Axis labels and title
plt.plot(x, y)

# x and y labels, and title
plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("Ohm's Law")

plt.show()

# %% [markdown]
# In the plot function, we can give various colors and styles of the line

# %%
# Change the colors and line type
# initialising x and y arrays
x = np.linspace(0, 10, 20)
y = x*2

# color blue, line type '^'. Try styles '+', '-', '--', '4', 'p'
plt.plot(x, y, 'b+')

# put x and y labels, and the title
plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("Ohm's Law")

plt.show()

# %%
# Plotting multiple lines on the same plot

x = np.linspace(0, 5, 10)
y = np.linspace(3, 6, 10)

# plot three curves: y, y**2 and y**3 with different line types
plt.plot(x, y, 'r--', x, y**2, 'b+', x, y**3, 'g^')
plt.show()

# %%
x = np.linspace(0, 5, 10)
y = np.linspace(3, 6, 10)

# plot three curves: y, y**2 and y**3 with different line types
plt.plot(x, y, 'r--')
plt.plot(x, y**2, 'b+')
plt.plot(x, y**3, 'g^')

# adding the legend in the plot
#plt.legend()
plt.show()

# %% [markdown]
# ## Figures and Subplots
#
# You often need to create multiple plots in the same figure.
#
#
# ```matplotlib``` has the concept of **figures and subplots** using which you can create *multiple subplots inside the same figure*.
#
# To create multiple plots in the same figure, you can use the method ```plt.subplot(nrows, ncols, nsubplot)```.

# %%
x = np.linspace(1, 10, 100)
y = np.log(x)

plt.figure(1)
plt.subplot(3,1,1)
plt.plot(x,y, 'r')
plt.xlabel("x vs y")

plt.figure(2)
plt.subplot(3,1,2)
plt.plot(x, y**2, 'y')
plt.xlabel("x vs y**2")


plt.figure(3)
plt.subplot(3,1,3)
plt.plot(x, y**3, 'b+')
plt.xlabel("x vs y**3")

plt.show()

# %%
x = np.linspace(1, 10, 100)
y = np.log(x)

# initiate a new figure explicitly 
plt.figure(1)

# Create a subplot with 1 row, 2 columns 

# create the first subplot in figure 1 
# equivalent to plt.subplot(1, 2, 1)
plt.subplot(1,2,1)
plt.title("y = log(x)")
plt.plot(x, y)

# create the second subplot in figure 1
plt.subplot(1,2,2)
plt.title("y = log(x)**2")
plt.plot(x, y**2)
plt.show()

# %% [markdown]
# Let's see another example - say you want to create 4 subplots in two rows and two columns.

# %%
# Example: Create a figure having 4 subplots
x = np.linspace(1, 10, 100)

# Optional command, since matplotlib creates a figure by default anyway
plt.figure(tight_layout=True)

# subplot 1
plt.subplot(2,2,1)
plt.title("Linear")
plt.plot(x, x)

# subplot 2 
plt.subplot(2,2,2)
plt.title("Cubic")
plt.plot(x, x**3)

# subplot 3
plt.figure(2)

plt.subplot(2,2,3)
plt.title("Log")
plt.plot(x, np.log(x))

# subplot 4 
plt.subplot(2,2,4)
plt.title("Square")
plt.plot(x, x**2)

plt.show()

# %% [markdown]
# You can see the list of colors and shapes here: https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot

# %% [markdown]
# ## Types of Plots

# %% [markdown]
# **1. Line Plot**
#
# Line plot can be used when we are trying to get the trends over a period of time, eg. Unemployment in India over the last 10 years.

# %%
import numpy as np

from matplotlib import pyplot as plt
x = np.linspace(0, 10, 20)
y = np.linspace(10, 0, 20)

plt.plot(x,y)

# show the plot
plt.show()

# %% [markdown]
# **2. Area Plot**
#
# Whenever we have to show multiple variables across time, then we use area plot. It represents cumulative totals using numbers or percentages over time.

# %% [markdown]
# 20-29
# 30-39
# 40-60
# 60-70

# %%
import pandas as pd

df = pd.DataFrame({
    'sales': [3, 2, 3, 9, 10, 6],
    'signups': [5, 5, 6, 12, 14, 13],
    'visits': [20, 42, 28, 62, 81, 50],
}, index=pd.date_range(start='2020/01/01', end='2020/07/01',
                       freq='M'))
df
# Out:
#             sales  signups  visits
# 2020-01-31      3        5      20
# 2020-02-29      2        5      42
# 2020-03-31      3        6      28
# 2020-04-30      9       12      62
# 2020-05-31     10       14      81
# 2020-06-30      6       13      50

# %%
df.plot.area()
plt.show()

# %% [markdown]
# **3. Bar Chart**
#
# When comparing various categories on the same variable, we use bar plots

# %%
names = ['apples', 'oranges', 'lemons', ' carrots', 'grapes']
amount = [10, 15, 30, 25, 20]

plt.bar(names, amount, color='green')
plt.xlabel('Names')
plt.ylabel('Amount')
plt.show()

# %%
data = {'Data Science':20, 'Machine Learning':15, 'Full Stack':30, 'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon', width = 0.6)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# **4. Scatter Plot**
#
# It is effective when we compare one variable across multiple subjects. Ex -  `How much actual sales happened for some marketing budget.`

# %%
names = ['apples', 'oranges', 'lemons', ' carrots', 'banana', 'tomatoes']
amount = [10, 15, 30, 25, 17, 23]

plt.scatter(names, amount,  s = 100,color='green')
plt.show()

# %%
year = [2012,2013,2014,2015,2016,2017]
population = [100,120,180,250,300,370]

plt.scatter(year, population)
plt.xlabel("Year")
plt.ylabel("Population in crores")
plt.show()

# %%
import pandas as pd

data = pd.read_csv("data/marketing_data.csv")
data.dropna(inplace=True)

# %%
data
# Out:
#     Marketing Budget (X) (In lakhs)  Actual Sales(Y) (In crores)
# 0                             127.4                         10.5
# 1                             364.4                         21.4
# 2                             150.0                         10.0
# 3                             128.7                          9.6
# 4                             285.9                         17.4
# 5                             200.0                         12.5
# 6                             303.3                         20.0
# 7                             315.7                         21.0
# 8                             169.8                         14.7
# 9                             104.9                         10.1
# 10                            297.7                         21.5
# 11                            256.4                         16.6
# 12                            249.1                         17.1
# ...

# %%
plt.scatter(data['Marketing Budget (X) (In lakhs)'], data['Actual Sales(Y) (In crores)'], s = 100 ,color='red', marker = '4')
plt.xlabel('Marketing Budget in Lakhs')
plt.ylabel('Sales Vales in Crores')
plt.grid(True)
plt.show()

# %% [markdown]
# **5. Histogram**
#
# Histogram is the plot used to show the frequency of continous or discrete variable.
#
# To show distribution of the data for a variable, we can use histogram.

# %%
numbers = [12,55,11,62,45,21,22,34,42,42,54,99,112,102,110,121,130,127,72,69,43,83,88,85]

plt.hist(numbers, bins=20)
plt.show()

# %%
plt.hist(data['Marketing Budget (X) (In lakhs)'], bins =5)
plt.show()

# %% [markdown]
# **6. Box Plots**
#
# Boxplot helps us get the summary of a data in very efficient manner. It helps us to find and analyse any outliers in the data.

# %%
import matplotlib.pyplot as plt
#%matplotlib inline

total = [20, 4, 1, 30, 20, 10, 20, 70, 30, 10]
discount = [30,20,10,5,20,10,60,20,40]
orders = [10,3,1,15,17,2,30,44,2,1]

data_list = [total,discount,orders]

plt.boxplot(data_list, showmeans=True)
plt.show()

# %% [markdown]
# **7. Image Plot**
#
# Image plot can be used for image manipulation. We can convert an image into numpy array and then use those values to plot an image.

# %%
image = plt.imread("data/Python-Symbol.jpg")
plt.imshow(image)
plt.show()

# %%
from PIL import Image

img = Image.open("data/Python-Symbol.jpg")
#arr = np.array(img)

plt.imshow(img)

# %% [markdown]
# **9. Pie Chart**
#
# We use it when we want to compare sub-parts of the whole data.

# %%
# Setting labels for items in Chart
Employee = ['Roshni', 'Shyam', 'Priyanshi','Harshit', 'Anmol']

# Setting size in Chart based on given values
Salary = [40000, 50000, 70000, 54000, 44000]

colors = ['Red', 'Green', 'Blue','Orange', 'Brown']
explosion_value = (0.25, 0.15, 0.0, 0.0, 0.0)

# Pie Chart
plt.pie(Salary, labels=Employee, explode=explosion_value, colors=colors)
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# ## Types of Commonly Used Plots
#
# Let's now use the retail store's sales data to create some commonly use plots such as:
# - Boxplots
# - Histograms
# - Scatter plots
# - Bar plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Example: Global sales data

market_df = pd.read_csv("data/market_fact.csv")
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market_df.shape
# Out:
# (8399, 10)

# %%
market_df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %% [markdown]
# ### Boxplot

# %%
# Boxplot of Sales is quite unreadable, since Sales varies 
# across a wide range
plt.boxplot(market_df['Sales'])
plt.show()

# %%
# Boxplot: Visualise the distribution of a continuous variable
plt.boxplot(market_df['Sales'])
plt.yscale("Log")
plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18776\2217779737.py:3: MatplotlibDeprecationWarning: Support for case-insensitive scales is deprecated since 3.5 and support will be removed two minor releases later.
#   plt.yscale("Log")

# %% [markdown]
# As you can see, the boxplot of ```Sales``` is pretty unreadable, since Sales varies across a wide range as shown below.

# %%
# Range of sales: min is 2.24, median is 449, max is 89061
market_df['Sales'].describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %% [markdown]
# The solution to this problem is to **change the scale of the axis** (in this case, the y axis) so that the range can fit into the size of the plot.
#
#
# One commonly used technique is to transform an axis into the **logarithmic scale**. You can transform the scale of an axis using ```plt.yscale('log')```.

# %%
# Usual (linear) scale subplot
plt.subplot(1, 2, 1)
plt.boxplot(market_df['Sales'])


# log scale subplot
plt.subplot(1, 2, 2)
plt.boxplot(market_df['Sales'])
plt.yscale('log')
plt.show()

# %% [markdown]
# Clearly, the log scale subplot is far more readable - you can infer that the minimum sales is around 0, the median is approximtely in the middle of 100 and 1000, and the max is reaching 100,000.

# %% [markdown]
# ### Histogram
#
# Histograms are useful for visualising distribution of single variables.

# %%
# The histogram can be made more readable by using 
# a log scale

plt.hist(market_df['Profit'])
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Scatter Plot
#
# Scatter plots are used to visualise two variables, one one each axis.

# %%
# Scatter plots with two variables: Profit and Sales
plt.scatter(market_df['Sales'], market_df['Profit'])
plt.show()

# %% [markdown]
# ## Working with Images
#
# ```matplotlib``` can also read images using the ```plt.imread()``` method. Internally, it reads and stores images as an ```array```. The array can then be used for various data manipulation tasks, just as a normal array.
# Let's look at an example.

# %%
# reading a PNG image
image = plt.imread("data/Python-Symbol.jpg")
plt.imshow(image)
plt.show()

# %%
# looking at attributes of the image 

print(type(image))
print(image.shape)
print(image.dtype)
# Out:
# <class 'numpy.ndarray'>
# (225, 225, 3)
# uint8

# %% [markdown]
# Note that it is a 3-D array of size 300 x 300 x 3, and each element is stored as type float32. Let's look at the content of the array.

# %%
# print the array
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# In the array, each inner list is of dimension size =3 and represents a pixel. Since this is an RGB image, there are 3 pixels (other types of images are RGBA, where A is alpha and represents transparency).

# %% [markdown]
# ## My Practise

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.arange(10)
y = x**2

plt.plot(x,y)

plt.show()

# %%
plt.plot(x,y,'b+')

# %%
plt.plot(x,y,'g^')

plt.plot(x,x+y, 'y*')

plt.plot(x,x-y, 'ko')
plt.show()

# %%
plt.plot(x,y,'k-')
plt.plot(x,x+y,'ro',x,x-y,'g*')
plt.title("Scatter plot - X & Y")
plt.xlabel("number")
plt.ylabel("calculation")
plt.xlim([0,10])
plt.ylim([-100,100])
plt.show()

# %%
plt.plot([1,3,5,7,9],[1,8,3,5,1],'y')
plt.xlabel("x")
plt.ylabel("y")
plt.xlim([0,10])
plt.ylim([0,10])
plt.title("Line Plot - X & Y")
plt.show()

# %%
plt.plot([160,180,146,162,184,180],[50,78,45,51,80,60],'ko')
plt.xlabel("Heights (cm)")
plt.ylabel("Weights (kg)")
plt.xlim([140,190])
plt.ylim([40,90])
plt.title("Scatter Plot - Heights & Weights")
plt.show()

# %%
# Multiple plots  in a single plot
x = np.arange(1,21)

y_1 = np.log(x)
y_2 = np.exp(x)

# Intilizing the Figure
plt.figure()

# row, clo, plot.no

# first col
plt.subplot(1,2,1) 

plt.plot(x,y_1)
plt.title("y = log(x)")


#2nd col
plt.subplot(1,2,2) 

plt.plot(x,y_2)
plt.title("y = exp(x)")

plt.show()

# %%
x = np.arange(1,101)

y_1 = np.log(x)
y_2 = np.exp(x)
y_3 = x**2
y_4 = x^2


plt.figure()
#plt.figure(tight_layout = True)

plt.subplots_adjust(wspace=0.5,hspace=1)
plt.subplot(2,2,1)

plt.plot(x,y_1)
plt.title("y = log(x)")



plt.subplot(2,2,2) 

plt.plot(x,y_2)
plt.title("y = exp(x)")

plt.subplot(2,2,3)
plt.plot(x,y_3)
plt.title("y = sq(x)")



plt.subplot(2,2,4) 

plt.plot(x,y_4)
plt.title("y = sqrt(x)")

plt.show()

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("data/Sample_Plot_Data.csv")

data.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# ...

# %%
print(data.shape)
print(data.ndim)
# Out:
# (173, 22)
# 2

# %%
data.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
plt.boxplot(data["Low_wage_jobs"])
plt.show()

# %%
plt.hist(data["Low_wage_jobs"])
plt.show()

# %%
plt.scatter(data["Women"],data["Unemployed"])

plt.show()

# %%
plt.scatter(data["Employed"],data["Men"])

# %%
data.plot(x="Unemployed",y=["Men","Women"])
plt.show()

# %%
data.plot(x="Rank", y=["P25th", "Median", "P75th"])
plt.show()

# %% [markdown]
# ## SeaBron

# %%
import seaborn as sns


sns.distplot(data["Women"])
sns.displot(data["Women"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(data["Women"])
# Out:
# <AxesSubplot:xlabel='Women', ylabel='Count'>

# %%
sns.displot(data["Women"],kind="hist")

# %%
sns.displot(data["Women"],kind="kde")

# %%
sns.displot(data=data,x='Women',y="Unemployed")

# %%
sns.displot(data=data,x='Women',y="Unemployed",kind='kde')

# %%
sns.displot(data=data,x='Women',y="Unemployed",kind='hist')

# %%
sns.boxplot(data=data,x="Women")
# Out:
# <AxesSubplot:xlabel='Women'>

# %%
sns.boxplot(data=data,x="Unemployed")
# Out:
# <AxesSubplot:xlabel='Unemployed'>

# %%
sns.jointplot(data=data,x="Women",y="Unemployed")

# %%
sns.jointplot(data=data,x="Women",y="Unemployed",kind='scatter')

# %%
sns.jointplot(data=data,x="Women",y="Unemployed",kind="hex",color='r')

# %%
sns.pairplot(data)

# %%
sns.pairplot(data=data,x_vars="Women",y_vars="Employed",hue="Major_category")

# %%
data.describe(include='object')
# Out:
#                         Major Major_category
# count                     173            173
# unique                    173             16
# top     PETROLEUM ENGINEERING    Engineering
# freq                        1             29

# %%
import seaborn as sns
import pandas as pd
import numpy as np

data = pd.read_csv("data/Violence Against Women  Girls Data.csv")

data.head()
# Out:
#    RecordID      Country Gender Demographics Question  \
# 0         1  Afghanistan      F        Marital status
# 1         1  Afghanistan      F             Education
# 2         1  Afghanistan      F             Education
# 3         1  Afghanistan      F             Education
# 4         1  Afghanistan      F        Marital status
#
#           Demographics Response                   Question Survey Year  Value
# 0                 Never married  ... if she burns the food  01/01/2015    NaN
# 1                        Higher  ... if she burns the food  01/01/2015   10.1
# 2                     Secondary  ... if she burns the food  01/01/2015   13.7
# 3                       Primary  ... if she burns the food  01/01/2015   13.8
# 4  Widowed, divorced, separated  ... if she burns the food  01/01/2015   13.8

# %%
data.describe(include='object')
# Out:
#             Country Gender Demographics Question Demographics Response  \
# count         12600  12600                 12600                 12600
# unique           70      2                     5                    15
# top     Afghanistan      F             Education         Never married
# freq            180   6300                  3360                   840
#
#                          Question Survey Year
# count                       12600       12600
# unique                          6          18
# top     ... if she burns the food  01/01/2013
# freq                         2100        1980

# %%
sns.stripplot(data=data, y='Value',x="Gender")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Value'>

# %%
country_data = data.loc[data.Country=='India',:]

country_data.head()
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 5580        32   India      F             Education                Higher
# 5581        32   India      F             Residence                 Urban
# 5582        32   India      F        Marital status         Never married
# 5583        32   India      F             Education             Secondary
# 5584        32   India      F                   Age                 15-24
#
#                        Question Survey Year  Value
# 5580  ... if she burns the food  01/01/2015   11.4
# 5581  ... if she burns the food  01/01/2015   15.2
# 5582  ... if she burns the food  01/01/2015   15.8
# 5583  ... if she burns the food  01/01/2015   17.3
# 5584  ... if she burns the food  01/01/2015   17.5

# %%
sns.boxplot(data=country_data, x='Gender',y="Value")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Value'>

# %%
sns.boxplot(data=country_data, x='Gender',y="Value",hue='Demographics Question')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Value'>

# %%
sns.barplot(data=country_data,x="Gender",y="Value")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Value'>

# %%
sns.barplot(data=country_data,x="Gender",y="Value",estimator=np.std)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Value'>

# %%
import matplotlib.pyplot as plt

plt.figure(tight_layout=True)
plt.subplot(1,2,1)
sns.barplot(data=country_data,x="Gender",y="Value")
plt.title("Mean")

plt.subplot(1,2,2)
sns.barplot(data=country_data,x="Gender",y="Value",estimator=np.median)
plt.title("Meadian")

plt.show()
